# %% [markdown]
# <a href="https://colab.research.google.com/github/sabihadudhia/Thesis-Hallucination-Benchmarks/blob/main/HaluEval_gptoss_20B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# 1. INSTALL DEPENDENCIES
# ============================================================
# !pip install -q transformers datasets accelerate bitsandbytes sentencepiece huggingface_hub tqdm pandas numpy scikit-learn
# !pip install "kernels>=0.16.0,<0.17.0"
# Out:
# Requirement already satisfied: kernels<0.17.0,>=0.16.0 in /usr/local/lib/python3.13/dist-packages (0.16.2)
# Requirement already satisfied: huggingface-hub>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (1.29.0)
# Requirement already satisfied: kernels-data>=0.14.0.dev1 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (0.16.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (26.3)
# Requirement already satisfied: pyyaml>=6 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (6.0.3)
# Requirement already satisfied: sigstore<5,>=4 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (4.5.0)
# Requirement already satisfied: tomlkit>=0.13.3 in /usr/local/lib/python3.13/dist-packages (from kernels<0.17.0,>=0.16.0) (0.14.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (4.16.0)
# Requirement already satisfied: cryptography>=42 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (50.0.1)
# Requirement already satisfied: id>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (1.6.1)
# Requirement already satisfied: pyasn1~=0.6 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.6.4)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.13.5)
# Requirement already satisfied: pyjwt>=2.1 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.13.0)
# Requirement already satisfied: pyOpenSSL>=23.0.0 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (26.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.32.4)
# Requirement already satisfied: rich<16,>=13 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (13.9.4)
# Requirement already satisfied: rfc8785~=0.1.2 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.1.4)
# Requirement already satisfied: rfc3161-client<1.1.0,>=1.0.3 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (1.0.9)
# Requirement already satisfied: sigstore-models==0.0.6 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.0.6)
# Requirement already satisfied: sigstore-rekor-types==0.0.18 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.0.18)
# Requirement already satisfied: tuf<8,>=6 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (7.0.1)
# Requirement already satisfied: platformdirs~=4.2 in /usr/local/lib/python3.13/dist-packages (from sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (4.11.7)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=42->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=1.10.0->kernels<0.17.0,>=0.16.0) (0.16.0)
# Requirement already satisfied: urllib3<3,>=2 in /usr/local/lib/python3.13/dist-packages (from id>=1.1.0->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich<16,>=13->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich<16,>=13->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.21.0)
# Requirement already satisfied: securesystemslib~=1.0 in /usr/local/lib/python3.13/dist-packages (from tuf<8,>=6->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (3.4.9)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=42->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich<16,>=13->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (0.1.2)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from pydantic[email]<3,>=2->sigstore-rekor-types==0.0.18->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from email-validator>=2.0.0->pydantic[email]<3,>=2->sigstore-rekor-types==0.0.18->sigstore<5,>=4->kernels<0.17.0,>=0.16.0) (2.8.0)

# %%
# ============================================================
# 2. IMPORTS
# ============================================================
import os, sys, json, random, subprocess, re
from datetime import datetime, timezone
import numpy as np
import pandas as pd
import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM

print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB

# %%
# ============================================================
# 3. REPRODUCIBILITY
# ============================================================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
print("Random seed:", SEED)
# Out:
# Random seed: 42

# %%
# ============================================================
# 4. CLONE HALUEVAL (skip if already present)
# ============================================================
if not os.path.exists("HaluEval"):
    subprocess.run(["git", "clone", "https://github.com/RUCAIBox/HaluEval.git", "HaluEval"], check=True)
halueval_commit = subprocess.check_output(["git", "-C", "HaluEval", "rev-parse", "HEAD"]).decode().strip()
print("HaluEval commit:", halueval_commit)
# Out:
# HaluEval commit: b7253db3cdaa0ab2c382f92b26b390109174f77e

# %%
# ============================================================
# 5. LOAD AND SAMPLE QA DATA
# ============================================================
with open('HaluEval/data/qa_data.json') as f:
    all_samples = [json.loads(line) for line in f]

random.seed(SEED)
sampled = random.sample(all_samples, 300)

instances = []
for s in sampled:
    instances.append({"knowledge": s["knowledge"], "question": s["question"],
                       "answer": s["right_answer"], "is_hallucinated_gt": False})
    instances.append({"knowledge": s["knowledge"], "question": s["question"],
                       "answer": s["hallucinated_answer"], "is_hallucinated_gt": True})

print(f"Total instances: {len(instances)}")
print(instances[0])
# Out:
# Total instances: 600
# {'knowledge': ' She is best known as a featured guest vocalist on several "Billboard" Hot 100 charting songs, such as G-Eazy\'s "Me, Myself & I", David Guetta\'s "Hey Mama", Martin Garrix\'s "In the Name of Love" and Cash Cash\'s "Take Me Home"."Hey Mama" is a song by French DJ and record producer David Guetta, featuring vocals from Nicki Minaj and Bebe Rexha, as well as production from Dutch DJ and producer Afrojack.', 'question': 'Bebe Rexha was a singer who guested on the David Guetta song that was produced by which Dutch DJ?', 'answer': 'Afrojack', 'is_hallucinated_gt': False}

# %%
# ============================================================
# 6. HUGGING FACE LOGIN AND LOAD GPT-OSS-20B
# ============================================================
from huggingface_hub import login
login()

MODEL_ID = "openai/gpt-oss-20b"

print("Loading:", MODEL_ID)
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype="auto",
    device_map="auto",
)
model.eval()
print("Model loaded.")

model_device = next(model.parameters()).device
print("Model device:", model_device)
# Out:
# Loading: openai/gpt-oss-20b
# metadata.json:   0%|          | 0.00/4.04k [00:00<?, ?B/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 42 files:   0%|          | 0/42 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/411 [00:00<?, ?it/s]
# Model loaded.
# Model device: cuda:0

# %%
# ============================================================
# 7. PROMPT FORMAT
# ============================================================
def build_prompt(instance):
    return (
        f"Knowledge: {instance['knowledge']}\n"
        f"Question: {instance['question']}\n"
        f"Answer: {instance['answer']}\n"
        f"Is the answer hallucinated?\n\nJudgment:"
    )

# %%
# ============================================================
# 8. SCORE ONE CANDIDATE (Yes or No)
# ============================================================
@torch.no_grad()
def score_answer_choice(prompt, answer_choice):
    full_text = prompt + " " + answer_choice

    prompt_tokens = tokenizer(prompt, return_tensors="pt", add_special_tokens=True)
    full_tokens = tokenizer(full_text, return_tensors="pt", add_special_tokens=True)

    prompt_ids = prompt_tokens["input_ids"]
    full_ids = full_tokens["input_ids"]

    if full_ids.shape[1] <= prompt_ids.shape[1]:
        raise ValueError("Candidate did not add any tokens.")

    full_inputs = {key: value.to(model_device) for key, value in full_tokens.items()}
    outputs = model(**full_inputs)
    logits = outputs.logits
    log_probs = torch.log_softmax(logits, dim=-1)

    full_ids = full_ids.to(model_device)
    candidate_start = prompt_ids.shape[1]
    candidate_token_ids = full_ids[0, candidate_start:]

    if candidate_token_ids.numel() == 0:
        raise ValueError("No candidate tokens found.")

    candidate_log_probs = []
    for token_position, token_id in enumerate(candidate_token_ids, start=candidate_start):
        prediction_position = token_position - 1
        token_log_prob = log_probs[0, prediction_position, token_id]
        candidate_log_probs.append(token_log_prob)

    candidate_log_probs = torch.stack(candidate_log_probs)
    return candidate_log_probs.sum().item()

# %%
# ============================================================
# 9. TEST ONE INSTANCE
# ============================================================
test_instance = instances[0]
test_prompt = build_prompt(test_instance)

yes_score = score_answer_choice(test_prompt, "Yes")
no_score = score_answer_choice(test_prompt, "No")

print("Prompt:\n", test_prompt)
print(f"\nYes: {yes_score:.4f}")
print(f"No:  {no_score:.4f}")
predicted = yes_score > no_score
print(f"\nPredicted hallucinated: {predicted}")
print(f"Ground truth hallucinated: {test_instance['is_hallucinated_gt']}")
# Out:
# Prompt:
#  Knowledge:  She is best known as a featured guest vocalist on several "Billboard" Hot 100 charting songs, such as G-Eazy's "Me, Myself & I", David Guetta's "Hey Mama", Martin Garrix's "In the Name of Love" and Cash Cash's "Take Me Home"."Hey Mama" is a song by French DJ and record producer David Guetta, featuring vocals from Nicki Minaj and Bebe Rexha, as well as production from Dutch DJ and producer Afrojack.
# Question: Bebe Rexha was a singer who guested on the David Guetta song that was produced by which Dutch DJ?
# Answer: Afrojack
# Is the answer hallucinated?
#
# Judgment:
#
# Yes: -3.4375
# No:  -3.5000
#
# Predicted hallucinated: True
# Ground truth hallucinated: False

# %%
# ============================================================
# 10. RUN COMPLETE HALUEVAL QA EVALUATION
# ============================================================
results = []
for instance_id, instance in enumerate(tqdm(instances, desc="Evaluating HaluEval QA")):
    prompt = build_prompt(instance)

    yes_score = score_answer_choice(prompt, "Yes")
    no_score = score_answer_choice(prompt, "No")

    predicted_hallucinated = yes_score > no_score
    correct = (predicted_hallucinated == instance["is_hallucinated_gt"])

    result = {
        "instance_id": instance_id,
        "knowledge": instance["knowledge"],
        "question": instance["question"],
        "answer": instance["answer"],
        "is_hallucinated_gt": instance["is_hallucinated_gt"],
        "yes_logprob": yes_score,
        "no_logprob": no_score,
        "predicted_hallucinated": predicted_hallucinated,
        "correct": bool(correct),
    }
    results.append(result)
# Out:
# Evaluating HaluEval QA:   0%|          | 0/600 [00:00<?, ?it/s]

# %%
# ============================================================
# 11. RESULTS DATAFRAME
# ============================================================
results_df = pd.DataFrame(results)
print("Number of evaluated instances:", len(results_df))
print("Correct:", results_df["correct"].sum())
print("Incorrect:", (~results_df["correct"]).sum())
# Out:
# Number of evaluated instances: 600
# Correct: 318
# Incorrect: 282

# %%
# ============================================================
# 12. ACCURACY
# ============================================================
accuracy = results_df["correct"].mean()
print(f"HaluEval QA accuracy: {accuracy:.4%}")
# Out:
# HaluEval QA accuracy: 53.0000%

# %%
# ============================================================
# 13. 95% BOOTSTRAP CONFIDENCE INTERVAL
# ============================================================
BOOTSTRAP_SEED = 42
N_BOOTSTRAPS = 10000
rng = np.random.default_rng(BOOTSTRAP_SEED)
correct_values = results_df["correct"].astype(int).to_numpy()

bootstrap_accuracies = []
for _ in range(N_BOOTSTRAPS):
    sample = rng.choice(correct_values, size=len(correct_values), replace=True)
    bootstrap_accuracies.append(sample.mean())

lower = np.percentile(bootstrap_accuracies, 2.5)
upper = np.percentile(bootstrap_accuracies, 97.5)
print(f"Accuracy: {accuracy:.4%}")
print(f"95% bootstrap CI: [{lower:.4%}, {upper:.4%}]")
# Out:
# Accuracy: 53.0000%
# 95% bootstrap CI: [49.0000%, 57.0000%]

# %%
# ============================================================
# 14. CONFUSION MATRIX / PER-CLASS ACCURACY
# ============================================================
hallucinated_subset = results_df[results_df["is_hallucinated_gt"] == True]
not_hallucinated_subset = results_df[results_df["is_hallucinated_gt"] == False]

print(f"Accuracy on hallucinated instances (should predict 'Yes'): {hallucinated_subset['correct'].mean():.4%}")
print(f"Accuracy on non-hallucinated instances (should predict 'No'): {not_hallucinated_subset['correct'].mean():.4%}")

true_positives = ((results_df["predicted_hallucinated"] == True) & (results_df["is_hallucinated_gt"] == True)).sum()
false_positives = ((results_df["predicted_hallucinated"] == True) & (results_df["is_hallucinated_gt"] == False)).sum()
true_negatives = ((results_df["predicted_hallucinated"] == False) & (results_df["is_hallucinated_gt"] == False)).sum()
false_negatives = ((results_df["predicted_hallucinated"] == False) & (results_df["is_hallucinated_gt"] == True)).sum()

print("\nConfusion matrix:")
print(f"                 Predicted Yes   Predicted No")
print(f"Actual Yes       {true_positives:<15}{false_negatives}")
print(f"Actual No        {false_positives:<15}{true_negatives}")
# Out:
# Accuracy on hallucinated instances (should predict 'Yes'): 55.6667%
# Accuracy on non-hallucinated instances (should predict 'No'): 50.3333%
#
# Confusion matrix:
#                  Predicted Yes   Predicted No
# Actual Yes       167            133
# Actual No        149            151

# %%
# ============================================================
# 15. INSPECT ONE PREDICTION
# ============================================================
def print_result(row):
    print("=" * 80)
    print("Instance ID:", row["instance_id"])
    print("\nKnowledge:", row["knowledge"][:200], "...")
    print("\nQuestion:", row["question"])
    print("Answer shown:", row["answer"])
    print(f"\nYes log-prob: {row['yes_logprob']:.4f}")
    print(f"No log-prob:  {row['no_logprob']:.4f}")
    print("\nGround truth hallucinated:", row["is_hallucinated_gt"])
    print("Predicted hallucinated:", row["predicted_hallucinated"])
    print("Result:", "CORRECT" if row["correct"] else "INCORRECT")

print_result(results_df.iloc[0])
# Out:
# ================================================================================
# Instance ID: 0
#
# Knowledge:  She is best known as a featured guest vocalist on several "Billboard" Hot 100 charting songs, such as G-Eazy's "Me, Myself & I", David Guetta's "Hey Mama", Martin Garrix's "In the Name of Love" and C ...
#
# Question: Bebe Rexha was a singer who guested on the David Guetta song that was produced by which Dutch DJ?
# Answer shown: Afrojack
#
# Yes log-prob: -3.4375
# No log-prob:  -3.5000
#
# Ground truth hallucinated: False
# Predicted hallucinated: True
# Result: INCORRECT

# %%
# ============================================================
# 16. SAVE RESULTS TO DRIVE
# ============================================================
from google.colab import drive
drive.mount('/content/drive')
os.makedirs('/content/drive/MyDrive/thesis_results', exist_ok=True)

RESULTS_FILE = "/content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.jsonl"
CSV_FILE = "/content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.csv"
METADATA_FILE = "/content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_metadata.json"

with open(RESULTS_FILE, "w", encoding="utf-8") as f:
    for result in results:
        f.write(json.dumps(result, ensure_ascii=False) + "\n")
print("Saved:", RESULTS_FILE)

csv_df = results_df.copy()
csv_df.to_csv(CSV_FILE, index=False, encoding="utf-8")
print("Saved:", CSV_FILE)
# Out:
# Mounted at /content/drive
# Saved: /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.jsonl
# Saved: /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.csv

# %%
# ============================================================
# 17. EXPERIMENT METADATA
# ============================================================
metadata = {
    "experiment": "HaluEval QA evaluation",
    "benchmark": "HaluEval",
    "task": "QA subset, Yes/No hallucination judgment",
    "sampling": "300 knowledge/question pairs (seed=42) -> 600 paired evaluation instances",
    "number_of_instances": len(instances),
    "model": MODEL_ID,
    "quantization": "native MXFP4 (as released; no additional quantization applied)",
    "seed": SEED,
    "scoring_method": "Log-probability comparison of 'Yes' vs 'No' completions; higher-scoring judgment selected.",
    "generation": False,
    "prompt_template": "Knowledge: {knowledge}\\nQuestion: {question}\\nAnswer: {answer}\\nIs the answer hallucinated?\\n\\nJudgment:",
    "software": {
        "python": sys.version,
        "pytorch": torch.__version__,
        "transformers": __import__("transformers").__version__,
    },
    "hardware": {
        "cuda_available": torch.cuda.is_available(),
        "gpu": torch.cuda.get_device_name(0) if torch.cuda.is_available() else None,
    },
    "halueval_commit": halueval_commit,
    "evaluation_timestamp_utc": datetime.now(timezone.utc).isoformat(),
}
with open(METADATA_FILE, "w", encoding="utf-8") as f:
    json.dump(metadata, f, indent=2, ensure_ascii=False)
print("Saved:", METADATA_FILE)
# Out:
# Saved: /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_metadata.json

# %%
# ============================================================
# 18. FINAL SUMMARY
# ============================================================
print("=" * 70)
print("HALUEVAL QA EVALUATION SUMMARY")
print("=" * 70)
print(f"Model: {MODEL_ID}")
print(f"Instances: {len(results_df)}")
print(f"Quantisation: native MXFP4")
print(f"Seed: {SEED}")
print()
print(f"Accuracy: {accuracy:.4%}")
print(f"95% bootstrap CI: [{lower:.4%}, {upper:.4%}]")
print(f"Accuracy on hallucinated instances: {hallucinated_subset['correct'].mean():.4%}")
print(f"Accuracy on non-hallucinated instances: {not_hallucinated_subset['correct'].mean():.4%}")
print()
print("Files:")
print("-", RESULTS_FILE)
print("-", CSV_FILE)
print("-", METADATA_FILE)
# Out:
# ======================================================================
# HALUEVAL QA EVALUATION SUMMARY
# ======================================================================
# Model: openai/gpt-oss-20b
# Instances: 600
# Quantisation: native MXFP4
# Seed: 42
#
# Accuracy: 53.0000%
# 95% bootstrap CI: [49.0000%, 57.0000%]
# Accuracy on hallucinated instances: 55.6667%
# Accuracy on non-hallucinated instances: 50.3333%
#
# Files:
# - /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.jsonl
# - /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_results.csv
# - /content/drive/MyDrive/thesis_results/halueval_gptoss20b_qa_metadata.json
